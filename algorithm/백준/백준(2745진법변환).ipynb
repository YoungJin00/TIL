# %%
# 2745 진법변환
decimal_num = 0
digit_map = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"

num, base = input().split()
base = int(base)

for i in range(len(num)):
    digit = num[-(i + 1)]
    decimal_num += digit_map.index(digit) * (base ** i)

print(decimal_num)
